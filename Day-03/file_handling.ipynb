# %%
# FILE HANDLING

# %%
# WRITING IN A FILE

import os
os.getenv('/Users/Administrator/Desktop/file_practice')
lst = open("siva1.txt","w")
lst.write("This is my first line \n")
lst.write("This is my second line \n")
lst.close()

# %%
#  READING A FILE

lst=open("siva1.txt","r")
lst.read()
# Out:
# 'This is my first line \nThis is my second line \n'

# %%
# READING A FILE WITH POINTER

lst=open("siva1.txt","r")
lst.read(4)
# Out:
# 'This'

# %%
a = "This is my file practice"
print(a[5:10])
# Out:
# is my

# %%
lst.tell()
# Out:
# 4

# %%
lst=open("siva.txt","r")
lst.read(10)
# Out:
# 'This is my'

# %%
# tell() --> Will help to tell where the cursor is currently pointing 

lst.tell()
# Out:
# 10

# %%
# seek() --> To reset the cursor 

lst.seek(20)
# Out:
# 20

# %%
lst.seek(0)
# Out:
# 0

# %%
# To read line by line

for line in lst:
    print(line)
# Out:
# This is my first line
#
# This is my second line

# %%
# To read one by one using builtin 

lst = open("siva1.txt","r")
lst.readline()
# Out:
# 'This is my first line \n'

# %%
lst.readline()
# Out:
# 'This is my second line \n'

# %%
import os
os.rename("siva.txt","nandy.txt")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Python\\Day-03'

# %%
os.chdir("/Users/Administrator/Desktop/file_practice")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\file_practice'

# %%
os.mkdir("nandhini")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\file_practice'

# %%
os.listdir(os.getcwdb())
# Out:
# [b'nandhini', b'siva.txt.txt']

# %%
#  MODULES

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 10, 51, 7, 14395)
