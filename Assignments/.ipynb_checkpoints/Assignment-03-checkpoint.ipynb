# %%
#  Create a directory
#  Put a file inside a directory
#  Delete, write data, read inside the directory
#  Delete the directory

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Python\\Day-03'

# %%
os.mkdir("Assignment02")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Python\\Day-03'

# %%
os.chdir('/Users/Administrator/Desktop/file_practice')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\file_practice'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\file_practice'

# %%
lst = open("practice-03.txt","w")
lst.write("This is my first file practice\n")
lst.close()

# %%
lst = open("practice-03.txt","r")
lst.read()
lst.close()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\file_practice'

# %%
import os
import shutil
shutil.rmtree("/Users/Administrator/Desktop/file_practice/Assignment01")
