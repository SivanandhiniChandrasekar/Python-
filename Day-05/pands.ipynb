# %%
Pandas

# %%
import pandas as pd
df = pd.read_csv(r"/Users/Administrator/Desktop/Python/Day-05/nyc_weather.csv")
df.head(10)
df.tail(30)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# ...

# %%
df.Events
df.Humidity

df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
# print(df.count)
print(df.Temperature.count)
# print(df.describe())
# print(df.shape)
# Out:
# <bound method Series.count of 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64>

# %%
df.WindSpeedMPH
df.WindSpeedMPH.isna()
df.WindSpeedMPH.isna().sum()
# Out:
# 3

# %%
#  ML Doesnt support string, character, and objects

# %%
df.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df.Events.unique()
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df.Events.describe()
# Out:
# count        9
# unique       3
# top       Rain
# freq         4
# Name: Events, dtype: object

# %%
df.CloudCover.unique()
# Out:
# array([5, 3, 1, 0, 8, 7, 4, 2, 6], dtype=int64)

# %%
df.Events
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df.Temperature.min()
# Out:
# 20

# %%
df1 = df.Temperature > 30
df1.sum()
# Out:
# 22

# %%
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['EST'] [df['Humidity'] == 70]
df['EST'] [df['Humidity'] >= 70]
df['EST'] [df['WindSpeedMPH'] == 7.0]
# Out:
# 1      1/2/2016
# 15    1/16/2016
# 25    1/26/2016
# 26    1/27/2016
# 29    1/30/2016
# Name: EST, dtype: object

# %%
df['EST'] [df['Temperature'] < 70].count()
# Out:
# 31

# %%
# Quick analysis, it will give details of matrix.

df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df['EST'] [df['Sea Level PressureIn'] >= 29].count()
# Out:
# 31

# %%
df['WindDirDegrees'] [df['Events'] == "Rain"]
# Out:
# 8      76
# 9     109
# 15    340
# 26    311
# Name: WindDirDegrees, dtype: int64

# %%
df['VisibilityMiles'] [df['Events'] == 'Rain']
# Out:
# 8      9
# 9      4
# 15     8
# 26    10
# Name: VisibilityMiles, dtype: int64

# %%
df['EST'] [df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.VisibilityMiles.max()
# Out:
# 10

# %%
df.VisibilityMiles.min()
# Out:
# 1

# %%
df[''][df['Temperature'] > 50].count()
# Out:
# 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.plot(df.Temperature, df.Humidity)
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.show()

# %%
import matplotlib.pyplot as plt

temp =  df['Temperature'] [df['Temperature'] > 40]
rain = df['Temperature'] [df['Temperature'] < 30]

plt.bar(temp,rain)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       3 temp =  df['Temperature'] [df['Temperature'] > 40]
#       4 rain = df['Temperature'] [df['Temperature'] < 30]
# ----> 6 plt.bar(temp,rain)
#       7 plt.show()
#
# File C:\Program Files\Python312\Lib\site-packages\matplotlib\pyplot.py:2870, in bar(x, height, width, bottom, align, data, **kwargs)
#    2859 @_copy_docstring_and_deprecators(Axes.bar)
#    2860 def bar(
#    2861     x: float | ArrayLike,
#    (...)
#    2868     **kwargs,
#    2869 ) -> BarContainer:
# -> 2870     return gca().bar(
#    2871         x,
#    2872         height,
#    2873         width=width,
#    2874         bottom=bottom,
#    2875         align=align,
#    2876         **({"data": data} if data is not None else {}),
#    2877         **kwargs,
#    2878     )
#
# ...
