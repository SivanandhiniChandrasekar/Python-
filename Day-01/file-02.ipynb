# %%
l1 = {1,2,3,4}
l2 = {1,3}
print(l2.issubset(l1))
print(l1.superset(l2))
# Out:
# True
# True

# %%
l1 = frozenset([0,1,2,3,4])
l2 = frozenset({9,8,7,6})
print(l2)
# l1.update(l2)
# Out:
# frozenset({8, 9, 6, 7})

# %%
# DICTIONARY
co = {1:'rajiv',2:'shyam'}
co[1] = 'raj'
print(type(co))
print(co[1])
print(co.get(1))
print(co.get(4)) # Exception handling also in get method
# Out:
# <class 'dict'>
# raj
# raj
# None

# %%
co = {1:'rajiv',2:'shyam',3:'raju',4:'Nirmala',5:'sathish'}
a= co.pop(2)
print(a)
print(co)

del co[1]
# print(c)

b = co.popitem() #LIFO for deleting
print(b)
print(co)

co.clear() #To delete entire dict
# Out:
# shyam
# {1: 'rajiv', 3: 'raju', 4: 'Nirmala', 5: 'sathish'}
# (5, 'sathish')
# {3: 'raju', 4: 'Nirmala'}

# %%
co = {1:'rajiv',2:'shyam',3:'raju',4:'Nirmala',5:'sathish'}
co2 = co.copy()
print(co)
print(co2)
print(id(co))
print(id(co2))
# Out:
# {1: 'rajiv', 2: 'shyam', 3: 'raju', 4: 'Nirmala', 5: 'sathish'}
# {1: 'rajiv', 2: 'shyam', 3: 'raju', 4: 'Nirmala', 5: 'sathish'}
# 2973948937536
# 2973948939072

# %%
sub = dict.fromkeys(['math','science','hindi'],0)
print(sub)
# Out:
# {'math': 0, 'science': 0, 'hindi': 0}

# %%
# To get values, keys separately
# items to display dict values more organized

co = {1:'rajiv',2:'shyam',3:'raju',4:'Nirmala',5:'sathish'}
print(co.keys())
print(co.values())
print(co.items())
# Out:
# dict_keys([1, 2, 3, 4, 5])
# dict_values(['rajiv', 'shyam', 'raju', 'Nirmala', 'sathish'])
# dict_items([(1, 'rajiv'), (2, 'shyam'), (3, 'raju'), (4, 'Nirmala'), (5, 'sathish')])

# %%
# To display all the functions
lid = {}
print(dir(lid))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
sq = {1:1,2:4,3:9,4:16,5:25}
d_sq = {k:v for k,v in sq.items() if v > 9}
d_sq
# Out:
# {4: 16, 5: 25}

# %%
dq = {k+5:v*2 for k,v in sq.items() if v > 4}
dq
# Out:
# {8: 18, 9: 32, 10: 50}
